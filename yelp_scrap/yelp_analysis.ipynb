# %% [markdown]
# ## Download Yelp business POI using the API

# %%
"""
Yelp Fusion API code sample.

This program demonstrates the capability of the Yelp Fusion API
by using the Search API to query for businesses by a search term and location,
and the Business API to query additional information about the top result
from the search query.

Please refer to https://docs.developer.yelp.com/docs/get-started for the API
documentation.
"""
from __future__ import print_function

import argparse
import json
import pprint
import requests
import sys
import urllib


# This client code can run on Python 2.x or 3.x.  Your imports can be
# simpler if you only need one of those.
try:
    # For Python 3.0 and later
    from urllib.error import HTTPError
    from urllib.parse import quote
    from urllib.parse import urlencode
except ImportError:
    # Fall back to Python 2's urllib2 and urllib
    from urllib2 import HTTPError
    from urllib import quote
    from urllib import urlencode


# Yelp Fusion no longer uses OAuth as of December 7, 2017.
# You no longer need to provide Client ID to fetch Data
# It now uses private keys to authenticate requests (API Key)
# You can find it on
# https://www.yelp.com/developers/v3/manage_app

# API constants, you shouldn't have to change these.
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  # Business ID will come after slash.


def request(host, path, api_key, url_params=None):
    """Given your API_KEY, send a GET request to the API.

    Args:
        host (str): The domain host of the API.
        path (str): The path of the API after the domain.
        API_KEY (str): Your API Key.
        url_params (dict): An optional set of query parameters in the request.

    Returns:
        dict: The JSON response from the request.

    Raises:
        HTTPError: An error occurs from the HTTP request.
    """
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
        #'Content - Language': 'en - US',
    }

    #print(u'Querying {0} ...'.format(url))

    response = requests.request('GET', url, headers=headers, params=url_params)

    return response.json()


def search(api_key, term, location):  # 
    """Query the Search API by a search term and location.

    Args:
        term (str): The search term passed to the API.
        business_id (str): The search business_id passed to the API.

    Returns:
        dict: The JSON response from the request.
    """
    url_params = {
        'location': location.replace(' ', '+'),
        'limit': search_limit  # ,
        #'offset': 1000
    }
    return request(API_HOST, SEARCH_PATH, api_key, url_params=url_params)


def get_business(api_key, business_id):
    """Query the Business API by a business ID.

    Args:
        business_id (str): The ID of the business to query.

    Returns:
        dict: The JSON response from the request.
    """
    business_path = BUSINESS_PATH + business_id

    return request(API_HOST, business_path, api_key)


def query_api(api_key, term, location, output_file):  # 
    """Queries the API by the input values from the user.

    Args:
        term (str): The search term to query.
        location (str): The location of the business to query.
    """
    response = search(api_key, term, location)  #

    businesses = response.get('businesses')

    if not businesses:
        print(u'No businesses in {0} found.'.format(location))
        return
    
    print(u'Searching for {0} in {1}; {2} businesses found; Output json file will be saved to {3}'.format(search_term,location, len(businesses), output_file))
    
    for business in businesses:
        business_id = business['id']
        print(u'\t querying business info for the result of business ID: "{0}" ...'.format(business_id))
        '''
        business_id = businesses[0]['id']

        print(u'{0} businesses found, querying business info '
              'for the top result "{1}" ...'.format(
                  len(businesses), business_id))
        '''
        response = get_business(api_key, business_id)
        #print(u'Result for business "{0}" found:'.format(business_id))
        #pprint.pprint(response, indent=2)

        # Save the response to a JSON file
        with open(output_file, 'a') as json_file:
            json.dump(response, json_file)
            json_file.write("\n")

# %%
# Set your API key
api_key = "paste_your_yelp_api_key_here"
search_term = 'restaurant' 
location = 'Athens, GA'
json_path = 'business.json'
search_limit = 50

# %%
try:
    query_api(api_key,search_term, location, json_path) 
except HTTPError as error:
    sys.exit('Encountered HTTP error {0} on {1}:\n {2}\nAbort program.'.format(
            error.code,
            error.url,
            error.read(),))
# Out:
# Searching for restaurant in Athens, GA; 50 businesses found; Output json file will be saved to business.json
# 	 querying business info for the result of business ID: "PTkAWaOk61zh1DRjUGUfcQ" ...
# 	 querying business info for the result of business ID: "PAfHPF4ea4fprm_Ji_ILxA" ...
# 	 querying business info for the result of business ID: "Upa0qxjMbVEaNTmpvTVANw" ...
# 	 querying business info for the result of business ID: "sEMCF4SI2RCzG7pBYr3Nsg" ...
# 	 querying business info for the result of business ID: "lMgGXIEU_4pkFpqdAwHGZw" ...
# 	 querying business info for the result of business ID: "10UVxiLX4eZZeypz8ffCwQ" ...
# 	 querying business info for the result of business ID: "XqUShUXJUSDPNhwXzqbqMg" ...
# 	 querying business info for the result of business ID: "db0uHZi_oRcevHqBD9pWKw" ...
# 	 querying business info for the result of business ID: "kif84V4moSrLUXNfZIJ03Q" ...
# 	 querying business info for the result of business ID: "A4gYyLPDHJxdU2Q4aZ2qIQ" ...
# 	 querying business info for the result of business ID: "hl5f1pB9ddsTiBq0YxOJrw" ...
# 	 querying business info for the result of business ID: "fUPJToWkyHlCIJed80tEvQ" ...
# 	 querying business info for the result of business ID: "bSse02O0u7Mee7lUo8Gk2Q" ...
# 	 querying business info for the result of business ID: "rmDWpuldPRZKXaTQdygM-g" ...
# 	 querying business info for the result of business ID: "AZUAtF9IrbFGM0EZdpbUtQ" ...
# 	 querying business info for the result of business ID: "mQEel-FH_aZooluKcyMRcg" ...
# 	 querying business info for the result of business ID: "DzfhzlDAqm2vesp0IJF3YA" ...
# 	 querying business info for the result of business ID: "PBHPyD9bsQbjUWQbKuaTxg" ...
# 	 querying business info for the result of business ID: "uxpdt4pFJfekRzj3TcoFrw" ...
# 	 querying business info for the result of business ID: "jnfIN8_SbZIwBRCrDvZyAA" ...
# 	 querying business info for the result of business ID: "nU9PcDONx9C_m6wyGaNfJw" ...
# 	 querying business info for the result of business ID: "JKvlo7OvcT8ZtGXptn9PGg" ...
# 	 querying business info for the result of business ID: "cdULqmmB-D3dHU7x9TU3Ug" ...
# 	 querying business info for the result of business ID: "-kAHBTWZ9ZB8XHZgaqhUKg" ...
# 	 querying business info for the result of business ID: "pAWYakjvdOi3s3nWFNVL7A" ...
# 	 querying business info for the result of business ID: "iG7_RvJqqXz2gunzvljAwg" ...
# 	 querying business info for the result of business ID: "6ztgIah3IaCLGrMmHpkBPQ" ...
# 	 querying business info for the result of business ID: "w8ZuImF8nmgP6BSxJQ4OcA" ...
# 	 querying business info for the result of business ID: "LJvZAsYjftb_AG1PpeIp9Q" ...
# 	 querying business info for the result of business ID: "--GZFmn6ffLLQuUkBj6_dQ" ...
# 	 querying business info for the result of business ID: "Py2ALEBS350Tr-uag7HLqQ" ...
# 	 querying business info for the result of business ID: "INBSHRHG3iNfuKrA2z5URw" ...
# 	 querying business info for the result of business ID: "2ymYkwJQXH8IkHBlqcNAOQ" ...
# 	 querying business info for the result of business ID: "m4piZgMKm_sMP-lnGhXF0w" ...
# 	 querying business info for the result of business ID: "3hLbBmg8OnBxEpbmHGkOLw" ...
# 	 querying business info for the result of business ID: "ZtJ8g2OAQ-cDn4v5sjfBqg" ...
# 	 querying business info for the result of business ID: "RFErbUuTZPGfNd2tulJFcA" ...
# 	 querying business info for the result of business ID: "DRR_7QMRNq44lZ7jCGz4Ww" ...
# 	 querying business info for the result of business ID: "aFITKJPD2y11-x-B4s3TdA" ...
# 	 querying business info for the result of business ID: "YHfS4ZJyjypf2-GvsB-ZjA" ...
# 	 querying business info for the result of business ID: "Jcds-gbFMQJ36wPHFeHzIw" ...
# 	 querying business info for the result of business ID: "fwa7LUEGZA2FZ6d1XYJ2XA" ...
# 	 querying business info for the result of business ID: "vsoCe5kLFVTTiS_Og0UeFg" ...
# 	 querying business info for the result of business ID: "4iSsEVcbcvJhO70pAtiHag" ...
# 	 querying business info for the result of business ID: "SExMdmokm5TjG7QtD0cRag" ...
# 	 querying business info for the result of business ID: "uSof0-dqrNb6LvNyxTtoUQ" ...
# 	 querying business info for the result of business ID: "kJYvEnZooyUsThZK95mNeQ" ...
# 	 querying business info for the result of business ID: "drn-MZI9WQCBGsAQmXgo5Q" ...
# 	 querying business info for the result of business ID: "4AMhhhovCL04i76K4H10-g" ...
# 	 querying business info for the result of business ID: "6CaqmfHqOeaPyJSpJrI4Eg" ...

# %% [markdown]
# # Read the output json file

# %% [markdown]
# ## Preparing Data
# In this section, we define the input parameters that our Moran's I tool will need. This includes:
# - The path to the feature class which contains our geographic data.
# - The name of the field that holds the attribute data we wish to analyze (in this case, 'rating').
# - The path where the output report will be saved.

# %% [markdown]
# ## Importing Modules
# In this cell, we are importing necessary Python modules that are required for our spatial analysis.
# - `arcpy`: The primary module for ArcGIS automation, which allows us to perform GIS tasks.
# - `arcpy.sa`: A submodule of `arcpy` for spatial analysis tasks.
# - `os`: A module that provides functions to interact with the operating system.

# %% [markdown]
# ## Setting the Workspace
# Here we set the workspace environment for ArcPy. The workspace is the foundational setting that establishes the working directory for any files that our script will use or produce. By setting it once at the beginning, we ensure that all subsequent operations look for files in the right place without needing to specify full paths.

# %%
import pandas as pd
json_path= json_path
csv_path = 'business.csv'
df = pd.read_json(json_path, lines=True)
df = df.drop_duplicates(subset='id', keep='first')

# Read the lon, lat columns
df['latitude'] = df['coordinates'].apply(lambda x: x['latitude'])
df['longitude'] = df['coordinates'].apply(lambda x: x['longitude'])

df
# Out:
#                          id                                     alias  \
# 0    Jcds-gbFMQJ36wPHFeHzIw             mamas-boy-at-the-falls-athens
# 1    PTkAWaOk61zh1DRjUGUfcQ                  last-resort-grill-athens
# 2    PAfHPF4ea4fprm_Ji_ILxA                       trappeze-pub-athens
# 30   https://www.yelp.com/biz/d-92-korean-bbq-athen...  17068507990
# 31   https://www.yelp.com/biz/viva-argentine-cuisin...  17068508284
# 32   https://www.yelp.com/biz/osteria-athena-athens...  17063533911
# 33   https://www.yelp.com/biz/the-farmcart-athens?a...  17068508150
# 34   https://www.yelp.com/biz/kellys-jamaican-foods...  17062080000
# 35   https://www.yelp.com/biz/bubble-cafe-athens?ad...  17063553002
# 36   https://www.yelp.com/biz/punta-cana-latin-gril...  17068508960
# 37   https://www.yelp.com/biz/big-city-bread-cafe-a...  17063530029
# 38   https://www.yelp.com/biz/thai-spoon-athens?adj...  17065489222
# 39   https://www.yelp.com/biz/maepole-athens-2?adju...  17068503600
# 40   https://www.yelp.com/biz/sakura-hibachi-and-su...  17068502027
# 41   https://www.yelp.com/biz/add-drug-store-athens...  17065482239
# 42   https://www.yelp.com/biz/mediterranean-grill-a...  17065435000
# 43   https://www.yelp.com/biz/hi-lo-lounge-athens?a...  17068508561
# 44   https://www.yelp.com/biz/zz-and-simone-s-athen...  17063956556
# 45   https://www.yelp.com/biz/white-tiger-gourmet-a...  17063536847
# 46   https://www.yelp.com/biz/bretts-restaurant-ath...  17068501395
# 47   https://www.yelp.com/biz/sr-sol-athens-3?adjus...  17065461570
# 48   https://www.yelp.com/biz/emmy-squared-pizza-at...  17623154005
# 49   https://www.yelp.com/biz/pauleys-original-crep...  17065490034
# 96   https://www.yelp.com/biz/food-for-the-soul-ath...  17065460052
# 97   https://www.yelp.com/biz/flying-biscuit-caf%C3...  17068505656
# 98   https://www.yelp.com/biz/hendershots-coffee-at...  17063533050
# 100  https://www.yelp.com/biz/40-watt-club-athens?a...  17065497871
#
#       display_phone  review_count  ... rating  \
# 0    (706) 850-8550           165  ...    4.0
# 1    (706) 549-0810           814  ...    4.0
# 2    (706) 543-8997           501  ...    4.0
# 3    (706) 850-2988           454  ...    4.5
# 4    (706) 395-6125           405  ...    4.0
# 5    (706) 850-4367           250  ...    4.5
# 6    (706) 395-6599           186  ...    4.5
# 7    (706) 549-7920           259  ...    4.5
# 8    (706) 548-6249           887  ...    4.5
# 9    (706) 549-3450           228  ...    4.5
# 10   (706) 206-9216           172  ...    4.5
# 11   (706) 227-9979           863  ...    4.5
# 12   (706) 548-3359           131  ...    4.0
# 13   (706) 850-7356            52  ...    4.5
# 14   (706) 850-3451           173  ...    4.0
# 15   (706) 621-7999           133  ...    4.0
# 16   (706) 478-0880           171  ...    4.0
# 17   (706) 549-6333           236  ...    4.0
# 18   (706) 546-7300           143  ...    3.5
# 19   (706) 395-6611           116  ...    4.0
# 20   (706) 353-7933           180  ...    4.0
# 21   (706) 613-9799           266  ...    4.5
# 22   (706) 543-5515           159  ...    4.0
# 23   (706) 355-7087           259  ...    4.5
# 24   (706) 521-5041            63  ...    4.5
# 25   (706) 548-9175           436  ...    4.0
# 26   (706) 353-0040           241  ...    4.0
# 27   (706) 395-6278            79  ...    4.0
# 28   (706) 543-1523           169  ...    4.0
# 29   (888) 978-7948           162  ...    4.0
# 30   (706) 850-7990           130  ...    4.0
# 31   (706) 850-8284           117  ...    4.5
# 32   (706) 353-3911            78  ...    4.0
# 33   (706) 850-8150           101  ...    4.5
# 34   (706) 208-0000           202  ...    4.5
# 35   (706) 355-3002            94  ...    4.5
# 36   (706) 850-8960           100  ...    4.5
# 37   (706) 353-0029           254  ...    4.0
# 38   (706) 548-9222           179  ...    4.0
# 39   (706) 850-3600           117  ...    4.5
# 40   (706) 850-2027            84  ...    3.5
# 41   (706) 548-2239            40  ...    4.5
# 42   (706) 543-5000           109  ...    4.0
# 43   (706) 850-8561            66  ...    4.5
# 44   (706) 395-6556            45  ...    4.0
# 45   (706) 353-6847           230  ...    4.5
# 46   (706) 850-1395           139  ...    4.5
# 47   (706) 546-1570           157  ...    4.5
# 48   (762) 315-4005            30  ...    4.5
# 49   (706) 549-0034           160  ...    3.5
# 96   (706) 546-0052            50  ...    4.5
# 97   (706) 850-5656            65  ...    3.5
# 98   (706) 353-3050           114  ...    4.5
# 100  (706) 549-7871            45  ...    4.5
#
#                                               location  \
# 0    {'address1': '8851 Macon Hwy', 'address2': 'St...
# 1    {'address1': '174-184 W Clayton St', 'address2...
# 2    {'address1': '269 N Hull St', 'address2': 'Ste...
# 3    {'address1': '229 E Broad St', 'address2': '',...
# 4    {'address1': '247 E Washington St', 'address2'...
# 5    {'address1': '297 Prince Ave', 'address2': 'St...
# 6    {'address1': '1075 Baxter St', 'address2': 'St...
# 7    {'address1': '1675 S Lumpkin St', 'address2': ...
# 8    {'address1': '197 Oak St', 'address2': '', 'ad...
# 9    {'address1': '232 W Hancock Ave', 'address2': ...
# 10   {'address1': '1072 Baxter St', 'address2': '',...
# 11   {'address1': '1427 S Lumpkin St', 'address2': ...
# 12   {'address1': '420 Macon Hwy Athens', 'address2...
# 13   {'address1': '235 W Washington St', 'address2'...
# 14   {'address1': '1195 S Milledge Ave', 'address2'...
# 15   {'address1': '320 E Clayton St', 'address2': '...
# 16   {'address1': '351 E Broad St', 'address2': Non...
# 17   {'address1': '1021 Pkwy Blvd', 'address2': 'St...
# 18   {'address1': '1073 S Milledge Ave', 'address2'...
# 19   {'address1': '220 W Broad St', 'address2': '',...
# 20   {'address1': '251 W Clayton St', 'address2': '...
# 21   {'address1': '224 W Hancock Ave', 'address2': ...
# 22   {'address1': '269 N Hull St', 'address2': 'Ste...
# 23   {'address1': '1254 Cedar Shoals Dr', 'address2...
# 24   {'address1': '1680 S Lumpkin St', 'address2': ...
# 25   {'address1': '259 W Washington St', 'address2'...
# 26   {'address1': '1791 Oconee Connector', 'address...
# 27   {'address1': '1235 Milledge Ave', 'address2': ...
# 28   {'address1': '254 W Washington St', 'address2'...
# 29   {'address1': '830 W Broad St', 'address2': Non...
# 30   {'address1': '1080 Baxter St', 'address2': Non...
# 31   {'address1': '247 Prince Ave', 'address2': '',...
# 32   {'address1': '323 E Broad St', 'address2': Non...
# 33   {'address1': '1074 Baxter St', 'address2': '',...
# 34   {'address1': '1583 S Lumpkin St', 'address2': ...
# 35   {'address1': '247 E Broad St', 'address2': Non...
# 36   {'address1': '367 Prince Ave', 'address2': 'St...
# 37   {'address1': '393 N Finley St', 'address2': No...
# 38   {'address1': '149 N Lumpkin St', 'address2': '...
# 39   {'address1': '1021 N Chase St', 'address2': No...
# 40   {'address1': '1225 S Milledge Ave', 'address2'...
# 41   {'address1': '1695 S Lumpkin St', 'address2': ...
# 42   {'address1': '1591 S Lumpkin St', 'address2': ...
# 43   {'address1': '1354 Prince Ave', 'address2': No...
# 44   {'address1': '1540 S Lumpkin St', 'address2': ...
# 45   {'address1': '217 Hiawassee Ave', 'address2': ...
# 46   {'address1': '3190 Atlanta Hwy', 'address2': '...
# 47   {'address1': '175 Tallassee Rd', 'address2': '...
# 48   {'address1': '199 Prince Ave', 'address2': Non...
# 49   {'address1': '134 E Clayton St', 'address2': '...
# 96   {'address1': '1965 W Broad St', 'address2': No...
# 97   {'address1': '1180 Prince Ave', 'address2': 'S...
# 98   {'address1': '237 Prince Ave', 'address2': '',...
# 100  {'address1': '285 W Washington St', 'address2'...
#
#                                            coordinates  \
# 0    {'latitude': 33.9095495614517, 'longitude': -8...
# 1     {'latitude': 33.958168, 'longitude': -83.378501}
# 2    {'latitude': 33.9586192714609, 'longitude': -8...
# 3    {'latitude': 33.95806332512856, 'longitude': -...
# 4    {'latitude': 33.9596729824125, 'longitude': -8...
# 5    {'latitude': 33.960074117071194, 'longitude': ...
# 6    {'latitude': 33.9464243857486, 'longitude': -8...
# 7    {'latitude': 33.93799428735798, 'longitude': -...
# 8    {'latitude': 33.9535827636719, 'longitude': -8...
# 9    {'latitude': 33.9595792, 'longitude': -83.3795...
# 10      {'latitude': 33.94765, 'longitude': -83.39806}
# 11   {'latitude': 33.9423784785634, 'longitude': -8...
# 12   {'latitude': 33.92116388464062, 'longitude': -...
# 13       {'latitude': 33.95845, 'longitude': -83.3792}
# 14    {'latitude': 33.939725, 'longitude': -83.386614}
# 15       {'latitude': 33.95852, 'longitude': -83.3742}
# 16      {'latitude': 33.958169, 'longitude': -83.3741}
# 17   {'latitude': 33.922336524631, 'longitude': -83...
# 18   {'latitude': 33.9415545, 'longitude': -83.3872...
# 19   {'latitude': 33.9571226762445, 'longitude': -8...
# 20      {'latitude': 33.95749, 'longitude': -83.37932}
# 21      {'latitude': 33.95966, 'longitude': -83.37937}
# 22   {'latitude': 33.9580247, 'longitude': -83.3787...
# 23   {'latitude': 33.9244835563217, 'longitude': -8...
# 24   {'latitude': 33.9375325116887, 'longitude': -8...
# 25      {'latitude': 33.95836, 'longitude': -83.37967}
# 26     {'latitude': 33.91589, 'longitude': -83.455244}
# 27   {'latitude': 33.9388577, 'longitude': -83.3863...
# 28      {'latitude': 33.95876, 'longitude': -83.37981}
# 29      {'latitude': 33.95578, 'longitude': -83.38608}
# 30   {'latitude': 33.947276218390925, 'longitude': ...
# 31   {'latitude': 33.9600227, 'longitude': -83.3828...
# 32     {'latitude': 33.958239, 'longitude': -83.37416}
# 33   {'latitude': 33.9474718942834, 'longitude': -8...
# 34      {'latitude': 33.93977, 'longitude': -83.38596}
# 35   {'latitude': 33.95799762516603, 'longitude': -...
# 36      {'latitude': 33.96005, 'longitude': -83.38385}
# 37       {'latitude': 33.9593, 'longitude': -83.38412}
# 38       {'latitude': 33.9578, 'longitude': -83.37709}
# 39   {'latitude': 33.969030000000004, 'longitude': ...
# 40      {'latitude': 33.93906, 'longitude': -83.38603}
# 41   {'latitude': 33.9373592, 'longitude': -83.3873...
# 42   {'latitude': 33.9396868569169, 'longitude': -8...
# 43   {'latitude': 33.9636116, 'longitude': -83.4007...
# 44   {'latitude': 33.94106360978481, 'longitude': -...
# 45      {'latitude': 33.96669, 'longitude': -83.39696}
# 46      {'latitude': 33.94201, 'longitude': -83.44923}
# 47   {'latitude': 33.9652366638184, 'longitude': -8...
# 48   {'latitude': 33.96008249383691, 'longitude': -...
# 49   {'latitude': 33.9580764770508, 'longitude': -8...
# 96    {'latitude': 33.951145, 'longitude': -83.402519}
# 97    {'latitude': 33.962664, 'longitude': -83.397145}
# 98    {'latitude': 33.960048, 'longitude': -83.382717}
# 100  {'latitude': 33.9581336975098, 'longitude': -8...
#
#                                                 photos price  \
# 0    [https://s3-media3.fl.yelpcdn.com/bphoto/75OoM...    $$
# 1    [https://s3-media4.fl.yelpcdn.com/bphoto/rOel6...    $$
# 2    [https://s3-media1.fl.yelpcdn.com/bphoto/eIcsI...    $$
# 3    [https://s3-media2.fl.yelpcdn.com/bphoto/0Gex4...    $$
# 4    [https://s3-media3.fl.yelpcdn.com/bphoto/l59XR...    $$
# 5    [https://s3-media3.fl.yelpcdn.com/bphoto/lOK48...    $$
# 6    [https://s3-media2.fl.yelpcdn.com/bphoto/LPXvY...    $$
# 7    [https://s3-media2.fl.yelpcdn.com/bphoto/BtLvS...    $$
# 8    [https://s3-media4.fl.yelpcdn.com/bphoto/we5zT...    $$
# 9    [https://s3-media1.fl.yelpcdn.com/bphoto/Thykf...   $$$
# 10   [https://s3-media3.fl.yelpcdn.com/bphoto/Zh71u...    $$
# 11   [https://s3-media4.fl.yelpcdn.com/bphoto/jtDxk...    $$
# 12   [https://s3-media4.fl.yelpcdn.com/bphoto/GReCb...    $$
# 13   [https://s3-media4.fl.yelpcdn.com/bphoto/OOSJZ...    $$
# 14   [https://s3-media1.fl.yelpcdn.com/bphoto/PdvJl...    $$
# 15   [https://s3-media3.fl.yelpcdn.com/bphoto/fX4q4...    $$
# 16   [https://s3-media2.fl.yelpcdn.com/bphoto/eysZE...    $$
# 17   [https://s3-media1.fl.yelpcdn.com/bphoto/vS7D-...    $$
# 18   [https://s3-media2.fl.yelpcdn.com/bphoto/fTx8h...   $$$
# 19   [https://s3-media2.fl.yelpcdn.com/bphoto/AFere...   NaN
# 20   [https://s3-media4.fl.yelpcdn.com/bphoto/2D7ln...    $$
# 21   [https://s3-media2.fl.yelpcdn.com/bphoto/uM5c_...    $$
# 22   [https://s3-media2.fl.yelpcdn.com/bphoto/5FzTg...    $$
# 23   [https://s3-media4.fl.yelpcdn.com/bphoto/tp7L4...    $$
# 24   [https://s3-media1.fl.yelpcdn.com/bphoto/46_D_...   NaN
# 25   [https://s3-media1.fl.yelpcdn.com/bphoto/W5bYV...    $$
# 26   [https://s3-media4.fl.yelpcdn.com/bphoto/3P77E...    $$
# 27   [https://s3-media2.fl.yelpcdn.com/bphoto/5XzUN...    $$
# 28   [https://s3-media1.fl.yelpcdn.com/bphoto/rNQem...    $$
# 29   [https://s3-media4.fl.yelpcdn.com/bphoto/z4rc_...    $$
# 30   [https://s3-media3.fl.yelpcdn.com/bphoto/NYT4B...   NaN
# 31   [https://s3-media1.fl.yelpcdn.com/bphoto/QfUuE...    $$
# 32   [https://s3-media1.fl.yelpcdn.com/bphoto/W_T0y...    $$
# 33   [https://s3-media4.fl.yelpcdn.com/bphoto/8feFW...    $$
# 34   [https://s3-media3.fl.yelpcdn.com/bphoto/MOBf-...    $$
# 35   [https://s3-media3.fl.yelpcdn.com/bphoto/Gt-KE...     $
# 36   [https://s3-media1.fl.yelpcdn.com/bphoto/T9JqJ...    $$
# 37   [https://s3-media3.fl.yelpcdn.com/bphoto/sXMQM...    $$
# 38   [https://s3-media1.fl.yelpcdn.com/bphoto/NJkPC...    $$
# 39   [https://s3-media2.fl.yelpcdn.com/bphoto/H3wh3...   NaN
# 40   [https://s3-media4.fl.yelpcdn.com/bphoto/Ru02q...   $$$
# 41   [https://s3-media1.fl.yelpcdn.com/bphoto/Dey6H...     $
# 42   [https://s3-media2.fl.yelpcdn.com/bphoto/7WF9L...     $
# 43   [https://s3-media3.fl.yelpcdn.com/bphoto/ldC1h...     $
# 44   [https://s3-media1.fl.yelpcdn.com/bphoto/eQHNO...   NaN
# 45   [https://s3-media2.fl.yelpcdn.com/bphoto/BGQ-t...    $$
# 46   [https://s3-media1.fl.yelpcdn.com/bphoto/Hpuf3...    $$
# 47   [https://s3-media2.fl.yelpcdn.com/bphoto/N6eZR...     $
# 48   [https://s3-media1.fl.yelpcdn.com/bphoto/Hozwx...   NaN
# 49   [https://s3-media1.fl.yelpcdn.com/bphoto/B-jTG...    $$
# 96   [https://s3-media1.fl.yelpcdn.com/bphoto/XF_A4...     $
# 97   [https://s3-media2.fl.yelpcdn.com/bphoto/rct2C...    $$
# 98   [https://s3-media2.fl.yelpcdn.com/bphoto/AZec2...     $
# 100  [https://s3-media1.fl.yelpcdn.com/bphoto/HwbE9...     $
#
#                                                  hours        transactions  \
# 0    [{'open': [{'is_overnight': False, 'start': '0...                  []
# 1    [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 2    [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 3    [{'open': [{'is_overnight': False, 'start': '1...  [delivery, pickup]
# 4    [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 5    [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 6    [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 7    [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 8    [{'open': [{'is_overnight': False, 'start': '0...          [delivery]
# 9    [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 10   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 11   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 12   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 13   [{'open': [{'is_overnight': False, 'start': '1...                  []
# 14   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 15   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 16   [{'open': [{'is_overnight': False, 'start': '1...  [pickup, delivery]
# 17   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 18   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 19   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 20   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 21   [{'open': [{'is_overnight': False, 'start': '1...  [pickup, delivery]
# 22   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 23   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 24   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 25   [{'open': [{'is_overnight': False, 'start': '1...  [pickup, delivery]
# 26   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 27   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 28   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 29   [{'open': [{'is_overnight': False, 'start': '1...  [delivery, pickup]
# 30   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 31   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 32   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 33   [{'open': [{'is_overnight': False, 'start': '0...                  []
# 34   [{'open': [{'is_overnight': False, 'start': '1...                  []
# 35   [{'open': [{'is_overnight': False, 'start': '1...  [pickup, delivery]
# 36   [{'open': [{'is_overnight': False, 'start': '1...  [pickup, delivery]
# 37   [{'open': [{'is_overnight': False, 'start': '0...          [delivery]
# 38   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 39   [{'open': [{'is_overnight': False, 'start': '1...  [pickup, delivery]
# 40   [{'open': [{'is_overnight': False, 'start': '1...  [pickup, delivery]
# 41   [{'open': [{'is_overnight': False, 'start': '0...          [delivery]
# 42   [{'open': [{'is_overnight': False, 'start': '1...            [pickup]
# 43   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 44   [{'open': [{'is_overnight': False, 'start': '1...                  []
# 45   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 46   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 47   [{'open': [{'is_overnight': False, 'start': '1...  [delivery, pickup]
# 48   [{'open': [{'is_overnight': False, 'start': '1...  [pickup, delivery]
# 49   [{'open': [{'is_overnight': True, 'start': '17...          [delivery]
# 96   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 97   [{'open': [{'is_overnight': False, 'start': '0...          [delivery]
# 98   [{'open': [{'is_overnight': False, 'start': '0...          [delivery]
# 100  [{'open': [{'is_overnight': True, 'start': '20...                  []
#
#                                              messaging   latitude  longitude
# 0                                                  NaN  33.909550 -83.402044
# 1                                                  NaN  33.958168 -83.378501
# 2                                                  NaN  33.958619 -83.378935
# 3                                                  NaN  33.958063 -83.375037
# 4                                                  NaN  33.959673 -83.375258
# 5                                                  NaN  33.960074 -83.383061
# 6                                                  NaN  33.946424 -83.400187
# 7                                                  NaN  33.937994 -83.387036
# 8                                                  NaN  33.953583 -83.365273
# 9    {'url': 'https://www.yelp.com/raq/kif84V4moSrL...  33.959579 -83.379585
# 10                                                 NaN  33.947650 -83.398060
# 11                                                 NaN  33.942378 -83.383788
# 12                                                 NaN  33.921164 -83.383509
# 13                                                 NaN  33.958450 -83.379200
# 14                                                 NaN  33.939725 -83.386614
# 15                                                 NaN  33.958520 -83.374200
# 16   {'url': 'https://www.yelp.com/raq/fUPJToWkyHlC...  33.958169 -83.374100
# 17                                                 NaN  33.922337 -83.441434
# 18                                                 NaN  33.941555 -83.387248
# 19                                                 NaN  33.957123 -83.378652
# 20                                                 NaN  33.957490 -83.379320
# 21                                                 NaN  33.959660 -83.379370
# 22                                                 NaN  33.958025 -83.378718
# 23                                                 NaN  33.924484 -83.332251
# 24                                                 NaN  33.937533 -83.387819
# 25                                                 NaN  33.958360 -83.379670
# 26   {'url': 'https://www.yelp.com/raq/Py2ALEBS350T...  33.915890 -83.455244
# 27                                                 NaN  33.938858 -83.386381
# 28                                                 NaN  33.958760 -83.379810
# 29                                                 NaN  33.955780 -83.386080
# 30                                                 NaN  33.947276 -83.399248
# 31                                                 NaN  33.960023 -83.382822
# 32                                                 NaN  33.958239 -83.374160
# 33                                                 NaN  33.947472 -83.398424
# 34                                                 NaN  33.939770 -83.385960
# 35                                                 NaN  33.957998 -83.374888
# 36                                                 NaN  33.960050 -83.383850
# 37   {'url': 'https://www.yelp.com/raq/LJvZAsYjftb_...  33.959300 -83.384120
# 38                                                 NaN  33.957800 -83.377090
# 39   {'url': 'https://www.yelp.com/raq/ZtJ8g2OAQ-cD...  33.969030 -83.392700
# 40                                                 NaN  33.939060 -83.386030
# 41   {'url': 'https://www.yelp.com/raq/RFErbUuTZPGf...  33.937359 -83.387351
# 42                                                 NaN  33.939687 -83.386174
# 43                                                 NaN  33.963612 -83.400772
# 44                                                 NaN  33.941064 -83.386025
# 45                                                 NaN  33.966690 -83.396960
# 46   {'url': 'https://www.yelp.com/raq/vsoCe5kLFVTT...  33.942010 -83.449230
# 47                                                 NaN  33.965237 -83.430290
# 48                                                 NaN  33.960082 -83.382321
# 49                                                 NaN  33.958076 -83.376534
# 96                                                 NaN  33.951145 -83.402519
# 97                                                 NaN  33.962664 -83.397145
# 98                                                 NaN  33.960048 -83.382717
# 100                                                NaN  33.958134 -83.380005
#
# [54 rows x 21 columns]

# %% [markdown]
# # Use arcpy for spatial analysis

# %% [markdown]
# ### Create business POI feature class from the Yelp data

# %%
import pandas as pd
import arcpy

# Assuming df is your pandas DataFrame with 'latitude' and 'longitude' columns

# Set the environment settings
arcpy.env.workspace = 'path_to_your_workspace'  # Replace with your workspace path
arcpy.env.overwriteOutput = 1

# Define a path for the new feature class
out_fc = 'business' # Replace with your file name

# Create an empty Point feature class
spatial_reference = arcpy.SpatialReference(4326)  # WGS 84
arcpy.management.CreateFeatureclass(arcpy.env.workspace, out_fc, 'POINT', '', '', '', spatial_reference)

# Use an insert cursor to add points
fields = ['SHAPE@XY', 'rating']

# Add the fields to the feature class
for field_name in fields[1:]:
    arcpy.management.AddField(out_fc, field_name, 'DOUBLE')  # You can change the field type as needed

# Open an InsertCursor to add points and attributes
with arcpy.da.InsertCursor(out_fc, fields) as cursor:
    for index, row in df.iterrows():
        # Extract values from the DataFrame row
        longitude = row['longitude']
        latitude = row['latitude']
        rating = row['rating']

        # Create a point geometry
        point = arcpy.Point(longitude, latitude)

        # Create a feature with the point geometry and attribute values
        feature = (point, rating)
        # Insert the feature into the feature class
        cursor.insertRow(feature)

# %% [markdown]
# ### Moran's I on the business data
# The Moran's I tool measures spatial autocorrelation based on feature locations and attribute values. We are running the tool with several parameters that specify how the spatial relationships are conceptualized (in this case, using an inverse distance method), the method for measuring distances (Euclidean), and how the data should be standardized.

# %%
# Check out any necessary licenses
arcpy.CheckOutExtension("spatial")

# Local variables:
input_feature_class = 'business.shp'  # Replace with your shapefile
input_field = 'rating'  # Replace with your field of interest

# Execute Spatial Autocorrelation (Moran's I)
Index, ZScore, PValue, Report_File = arcpy.stats.SpatialAutocorrelation(
    Input_Feature_Class=input_feature_class,
    Input_Field=input_field,
    Generate_Report="GENERATE_REPORT", 
    Conceptualization_of_Spatial_Relationships="INVERSE_DISTANCE", 
    Distance_Method="EUCLIDEAN_DISTANCE", 
    Standardization="ROW"
)

# Check in any necessary licenses
arcpy.CheckInExtension("spatial")

print(f"Moran's I Analysis Finished!\nIndex: {Index}\nZScore: {ZScore}\nPValue: {PValue}\nReport File: {Report_File}")
# Out:
# Moran's I Analysis Finished!
# Index: 0.107773
# ZScore: 2.098428
# PValue: 0.035867
# Report File: C:\Users\54475\AppData\Local\Temp\MoransI_Result_20152_18740_.html
